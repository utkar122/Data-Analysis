# %% [markdown]
# # Pre Processing Data

# %%
# import required library
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading Data
train = pd.read_csv(r'/content/Train.csv')
test = pd.read_csv(r'/content/Test.csv')

# %%
# Checking top 5 row of train data
train.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
# checking top 5 row of test data
test.head()
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Location_Type        Outlet_Type
# 0           FDW58       20.750  ...               Tier 1  Supermarket Type1
# 1           FDW14        8.300  ...               Tier 2  Supermarket Type1
# 2           NCN55       14.600  ...               Tier 3      Grocery Store
# 3           FDQ58        7.315  ...               Tier 2  Supermarket Type1
# 4           FDY38          NaN  ...               Tier 3  Supermarket Type3
#
# [5 rows x 11 columns]

# %%
# checking Missing values in train data
train.isnull().sum()/len(train)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
# checking Missing values in test data
test.isnull().sum()/len(test)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.180074
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.269671
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# dtype: float64

# %%
# check data type 
train.dtypes,test.dtypes
# Out:
# (Item_Identifier               object
#  Item_Weight                  float64
#  Item_Fat_Content              object
#  Item_Visibility              float64
#  Item_Type                     object
#  Item_MRP                     float64
#  Outlet_Identifier             object
#  Outlet_Establishment_Year      int64
#  Outlet_Size                   object
#  Outlet_Location_Type          object
#  Outlet_Type                   object
#  Item_Outlet_Sales            float64
#  dtype: object, Item_Identifier               object
#  Item_Weight                  float64
#  Item_Fat_Content              object
#  Item_Visibility              float64
#  Item_Type                     object
#  Item_MRP                     float64
#  Outlet_Identifier             object
#  Outlet_Establishment_Year      int64
#  Outlet_Size                   object
#  Outlet_Location_Type          object
#  Outlet_Type                   object
#  dtype: object)

# %% [markdown]
# # Filling the Missing Values

# %%
train['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0], inplace=True)
train['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace=True)
test['Outlet_Size'].fillna(test['Outlet_Size'].mode()[0], inplace=True)
test['Item_Weight'].fillna(test['Item_Weight'].mean(), inplace=True)

# %%
# checking the missing values
train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# # Create Dummy variables of categorical data

# %%
train = pd.get_dummies(train, columns = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],prefix = '',prefix_sep = '')
test = pd.get_dummies(test, columns = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],prefix = '',prefix_sep = '')

# %%
train = pd.get_dummies(train, columns = ['Outlet_Identifier'],prefix = '',prefix_sep = '')
test = pd.get_dummies(test, columns = ['Outlet_Identifier'],prefix = '',prefix_sep = '')

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  ...  OUT045  OUT046  OUT049
# 0           FDA15         9.30         0.016047  ...       0       0       1
# 1           DRC01         5.92         0.019278  ...       0       0       0
# 2           FDN15        17.50         0.016760  ...       0       0       1
# 3           FDX07        19.20         0.000000  ...       0       0       0
# 4           NCD19         8.93         0.000000  ...       0       0       0
#
# [5 rows x 47 columns]

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  ...  OUT045  OUT046  OUT049
# 0           FDW58    20.750000         0.007565  ...       0       0       1
# 1           FDW14     8.300000         0.038428  ...       0       0       0
# 2           NCN55    14.600000         0.099575  ...       0       0       0
# 3           FDQ58     7.315000         0.015388  ...       0       0       0
# 4           FDY38    12.695633         0.118599  ...       0       0       0
#
# [5 rows x 46 columns]

# %% [markdown]
# # Data Scaling

# %%
for i in train.columns[1:]:
    train[i] = (train[i] - train[i].min()) / (train[i].max() - train[i].min())

# %%
for i in test.columns[1:]:
    test[i] = (test[i] - test[i].min()) / (test[i].max() - test[i].min())

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  ...  OUT045  OUT046  OUT049
# 0           FDA15     0.282525         0.048866  ...     0.0     0.0     1.0
# 1           DRC01     0.081274         0.058705  ...     0.0     0.0     0.0
# 2           FDN15     0.770765         0.051037  ...     0.0     0.0     1.0
# 3           FDX07     0.871986         0.000000  ...     0.0     0.0     0.0
# 4           NCD19     0.260494         0.000000  ...     0.0     0.0     0.0
#
# [5 rows x 47 columns]

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  ...  OUT045  OUT046  OUT049
# 0           FDW58     0.964275         0.023374  ...     0.0     0.0     1.0
# 1           FDW14     0.222983         0.118737  ...     0.0     0.0     0.0
# 2           NCN55     0.598095         0.307674  ...     0.0     0.0     0.0
# 3           FDQ58     0.164335         0.047548  ...     0.0     0.0     0.0
# 4           FDY38     0.484706         0.366458  ...     0.0     0.0     0.0
#
# [5 rows x 46 columns]

# %%
train = train.drop('Item_Identifier', axis=1)
test = test.drop('Item_Identifier', axis=1)

# %%
train.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  ...  OUT045  OUT046  OUT049
# 0     0.282525         0.048866  0.927507  ...     0.0     0.0     1.0
# 1     0.081274         0.058705  0.072068  ...     0.0     0.0     0.0
# 2     0.770765         0.051037  0.468288  ...     0.0     0.0     1.0
# 3     0.871986         0.000000  0.640093  ...     0.0     0.0     0.0
# 4     0.260494         0.000000  0.095805  ...     0.0     0.0     0.0
#
# [5 rows x 46 columns]

# %%
test.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  ...  OUT045  OUT046  OUT049
# 0     0.964275         0.023374  0.323413  ...     0.0     0.0     1.0
# 1     0.222983         0.118737  0.235849  ...     0.0     0.0     0.0
# 2     0.598095         0.307674  0.894140  ...     0.0     0.0     0.0
# 3     0.164335         0.047548  0.524488  ...     0.0     0.0     0.0
# 4     0.484706         0.366458  0.862069  ...     0.0     0.0     0.0
#
# [5 rows x 45 columns]

# %%
# separating the independent and dependent variables

# storing all the independent variables as X
X = train.drop('Item_Outlet_Sales', axis=1)

# storing the dependent variable as y
y = train['Item_Outlet_Sales']

# %% [markdown]
# # Create train and validation

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=10,test_size=0.2)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((6818, 45), (6818,)), ((1705, 45), (1705,)))

# %% [markdown]
# # XGBOOST

# %%
from xgboost.sklearn import XGBRegressor
XGB = XGBRegressor()
XGB.fit(X_train, y_train)
y_pred = XGB.predict(X_test)
# Out:
# [23:20:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test, y_pred))

# %%
from sklearn.metrics import r2_score,accuracy_score
r2_score(y_test,y_pred)
# Out:
# 0.6046291879980492

# %%
rmse
# Out:
# 0.08299111276592988

# %%
y_result = XGB.predict(test)

# %%
y_result
# Out:
# array([0.12553725, 0.10146147, 0.04444227, ..., 0.13697061, 0.2901865 ,
#        0.09519181], dtype=float32)

# %% [markdown]
# # Neural Network

# %% [markdown]
# # Defining the architecture of the model

# %%
# checking the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# checking the version of tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Create Model

# %%
# importing the sequential model
from keras.models import Sequential

# %% [markdown]
# # Defining different layers

# %%
# importing different layers from keras
from keras.layers import InputLayer, Dense,Flatten,Dropout

# %%
# number of input neurons
X_train.shape
# Out:
# (6818, 45)

# %%
# number of features in the data
X_train.shape[1]
# Out:
# 45

# %%
model = Sequential()

# %%
#Input Layer
model.add(Dense(128,kernel_initializer='normal',input_shape=(X_train.shape[1],),activation='relu'))

# %%
#Hidden Layers
model.add(Dense(256,kernel_initializer='normal',activation='relu'))
model.add(Dense(256,kernel_initializer='normal',activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256,kernel_initializer='normal',activation='relu'))

# %%
#Output Layer
model.add(Dense(1,kernel_initializer='normal',activation='linear'))

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               5888
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 170,753
# Trainable params: 170,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compiling the model (defining loss function, optimizer)

# %%
model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mean_absolute_error'])

# %% [markdown]
# # Training the Model

# %%
# training the model

# passing the independent and dependent features for training set for training the model

# validation data will be evaluated at the end of each epoch

# setting the epochs as 50

# storing the trained model in model_history variable which will be used to visualize the training process

model_history = model.fit(X_train,y_train,epochs=300,batch_size=60,validation_split=0.2)
# Out:
# Epoch 1/300
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 2/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0614 - mean_absolute_error: 0.0614 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588
# Epoch 3/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0592 - mean_absolute_error: 0.0592 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585
# Epoch 4/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583
# Epoch 5/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0583 - mean_absolute_error: 0.0583 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583
# Epoch 6/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0588 - mean_absolute_error: 0.0588 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586
# Epoch 7/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0595 - mean_absolute_error: 0.0595 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578
# Epoch 8/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0586 - mean_absolute_error: 0.0586 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581
# Epoch 9/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579
# Epoch 10/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588
# Epoch 11/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588
# Epoch 12/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594
# Epoch 13/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616
# Epoch 14/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0582 - mean_absolute_error: 0.0582 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586
# Epoch 15/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 16/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 17/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585
# Epoch 18/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587
# Epoch 19/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597
# Epoch 20/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605
# Epoch 21/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590
# Epoch 22/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 23/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589
# Epoch 24/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589
# Epoch 25/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599
# Epoch 26/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584
# Epoch 27/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596
# Epoch 28/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585
# Epoch 29/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607
# Epoch 30/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0530 - mean_absolute_error: 0.0530 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600
# Epoch 31/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593
# Epoch 32/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0530 - mean_absolute_error: 0.0530 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615
# Epoch 33/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0520 - mean_absolute_error: 0.0520 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595
# Epoch 34/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0519 - mean_absolute_error: 0.0519 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600
# Epoch 35/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600
# Epoch 36/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0524 - mean_absolute_error: 0.0524 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606
# Epoch 37/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 38/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0519 - mean_absolute_error: 0.0519 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609
# Epoch 39/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609
# Epoch 40/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613
# Epoch 41/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0485 - mean_absolute_error: 0.0485 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612
# Epoch 42/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0506 - mean_absolute_error: 0.0506 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608
# Epoch 43/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0500 - mean_absolute_error: 0.0500 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603
# Epoch 44/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0504 - mean_absolute_error: 0.0504 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613
# Epoch 45/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0492 - mean_absolute_error: 0.0492 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615
# Epoch 46/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636
# Epoch 64/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0450 - mean_absolute_error: 0.0450 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630
# Epoch 65/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0640 - val_mean_absolute_error: 0.0640
# Epoch 66/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0434 - mean_absolute_error: 0.0434 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632
# Epoch 67/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636
# Epoch 68/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0640 - val_mean_absolute_error: 0.0640
# Epoch 69/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0624 - val_mean_absolute_error: 0.0624
# Epoch 70/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632
# Epoch 71/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0443 - mean_absolute_error: 0.0443 - val_loss: 0.0645 - val_mean_absolute_error: 0.0645
# Epoch 72/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0645 - val_mean_absolute_error: 0.0645
# Epoch 73/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632
# Epoch 74/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.0423 - val_loss: 0.0640 - val_mean_absolute_error: 0.0640
# Epoch 75/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0420 - mean_absolute_error: 0.0420 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649
# Epoch 76/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0635 - val_mean_absolute_error: 0.0635
# Epoch 77/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634
# Epoch 78/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0402 - mean_absolute_error: 0.0402 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634
# Epoch 79/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0397 - mean_absolute_error: 0.0397 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641
# Epoch 80/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652
# Epoch 81/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631
# Epoch 82/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644
# Epoch 83/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643
# Epoch 84/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0403 - mean_absolute_error: 0.0403 - val_loss: 0.0653 - val_mean_absolute_error: 0.0653
# Epoch 85/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643
# Epoch 86/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650
# Epoch 87/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654
# Epoch 88/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0388 - mean_absolute_error: 0.0388 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664
# Epoch 89/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0663 - val_mean_absolute_error: 0.0663
# Epoch 90/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646
# Epoch 91/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654
# Epoch 92/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652
# Epoch 93/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0675 - val_mean_absolute_error: 0.0675
# Epoch 94/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652
# Epoch 95/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659
# Epoch 96/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654
# Epoch 97/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0670 - val_mean_absolute_error: 0.0670
# Epoch 219/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 220/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 221/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0245 - mean_absolute_error: 0.0245 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 222/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0242 - mean_absolute_error: 0.0242 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 223/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 224/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0245 - mean_absolute_error: 0.0245 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 225/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - val_loss: 0.0688 - val_mean_absolute_error: 0.0688
# Epoch 226/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 227/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0243 - mean_absolute_error: 0.0243 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683
# Epoch 228/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693
# Epoch 229/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0242 - mean_absolute_error: 0.0242 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 230/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0238 - mean_absolute_error: 0.0238 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687
# Epoch 231/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0234 - mean_absolute_error: 0.0234 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 232/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694
# Epoch 233/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0238 - mean_absolute_error: 0.0238 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 234/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685
# Epoch 235/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 236/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.0690 - val_mean_absolute_error: 0.0690
# Epoch 237/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687
# Epoch 238/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684
# Epoch 239/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0238 - mean_absolute_error: 0.0238 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 240/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0231 - mean_absolute_error: 0.0231 - val_loss: 0.0688 - val_mean_absolute_error: 0.0688
# Epoch 241/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0245 - mean_absolute_error: 0.0245 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677
# Epoch 242/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0244 - mean_absolute_error: 0.0244 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687
# Epoch 243/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0237 - mean_absolute_error: 0.0237 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 244/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 245/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0235 - mean_absolute_error: 0.0235 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 246/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0229 - mean_absolute_error: 0.0229 - val_loss: 0.0682 - val_mean_absolute_error: 0.0682
# Epoch 247/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0237 - mean_absolute_error: 0.0237 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 248/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0226 - mean_absolute_error: 0.0226 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 249/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 250/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 251/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 252/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 253/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0231 - mean_absolute_error: 0.0231 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 254/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 255/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 256/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 257/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 258/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 259/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0222 - mean_absolute_error: 0.0222 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692
# Epoch 260/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 261/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 262/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692
# Epoch 263/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 264/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725
# Epoch 265/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685
# Epoch 266/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 267/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0227 - mean_absolute_error: 0.0227 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 268/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0225 - mean_absolute_error: 0.0225 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 269/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 270/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 271/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0222 - mean_absolute_error: 0.0222 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 272/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0234 - mean_absolute_error: 0.0234 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 273/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 274/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 275/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.0218 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 276/300
# 91/91 [==============================] - 1s 5ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 277/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - val_loss: 0.0739 - val_mean_absolute_error: 0.0739
# Epoch 278/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 279/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 280/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0211 - mean_absolute_error: 0.0211 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 281/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0219 - mean_absolute_error: 0.0219 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 282/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 283/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 284/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0213 - mean_absolute_error: 0.0213 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685
# Epoch 285/300
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0218 - mean_absolute_error: 0.0218 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 286/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 287/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686
# Epoch 288/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 289/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 290/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0218 - mean_absolute_error: 0.0218 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 291/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0212 - mean_absolute_error: 0.0212 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 292/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0220 - mean_absolute_error: 0.0220 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 293/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687
# Epoch 294/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 295/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0199 - mean_absolute_error: 0.0199 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 296/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0215 - mean_absolute_error: 0.0215 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686
# Epoch 297/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0224 - mean_absolute_error: 0.0224 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 298/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 299/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 300/300
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710

# %%
# getting predictions for the validation set
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([[0.22516808],
#        [0.10532391],
#        [0.13187492],
#        ...,
#        [0.05947281],
#        [0.23188484],
#        [0.2526656 ]], dtype=float32)

# %%
r2_score(y_test,prediction)
# Out:
# 0.3403195102114204

# %%
# getting predictions for the test set
prediction1 = model.predict(test)

# %%
prediction1
# Out:
# array([[0.10563298],
#        [0.06571661],
#        [0.03467903],
#        ...,
#        [0.13144921],
#        [0.18560371],
#        [0.11984962]], dtype=float32)

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(model_history.history['mean_absolute_error'])
plt.plot(model_history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
